# %%
import numpy as np
import matplotlib as plt
import pandas as pd
import seaborn as sns

# %%
test_run = pd.read_csv("/Users/jerryhuang/Documents/PIPpolarization/data/test_run_10000.csv")

# %%
test_run.head()
# Out:
#    Total Kinase  Total Phosphatase  Timestep  Patch Length      dPIP  \
# 0    504.587309        1072.584374      0.01           0.5  2.392294
# 1    404.712736         907.375976      0.01           0.5  3.635594
# 2    516.268104         883.646691      0.01           0.5  3.798411
# 3    487.519247        1006.473821      0.01           0.5  3.112764
# 4    509.134552        1004.967042      0.01           0.5  2.617439
#
#    alphaEnzyme    k_mkon    k_koff    p_mkon    p_koff    k_mkcat     k_mKm  \
# 0     0.230912  0.325587  0.492680  0.046112  0.207982  10.810666  2.077767
# 1     0.191769  0.394807  0.542681  0.049611  0.158331  12.699161  3.605082
# 2     0.187384  0.286262  0.466465  0.046303  0.188547   7.578705  3.439337
# 3     0.161575  0.317702  0.579028  0.052530  0.176516  12.421751  3.634139
# 4     0.177708  0.333110  0.580674  0.047376  0.155150   9.781921  3.522384
#
#      p_mkcat     p_mKm  Kinase in solution  Phosphatase in solution  \
# 0  14.983961  0.405463                 353                     1127
# 1  15.819867  0.473824                 264                      703
# 2  13.025158  0.561078                 398                      857
# 3  13.561162  0.592447                 430                      873
# 4  17.515967  0.487298                 430                      890
#
#    Average system X  Average dendrite X  Polarization index
# 0          0.515847            0.546400            0.516679
# 1          0.525752            0.560122            0.516003
# 2          0.515301            0.559077            0.521605
# 3          0.523906            0.560070            0.516021
# 4          0.555038            0.618737            0.525549

# %%
test_run["Polarized"] = test_run["Polarization index"].map(lambda x: x >= 0.8)
test_run.head()
# Out:
#    Total Kinase  Total Phosphatase  Timestep  Patch Length      dPIP  \
# 0    504.587309        1072.584374      0.01           0.5  2.392294
# 1    404.712736         907.375976      0.01           0.5  3.635594
# 2    516.268104         883.646691      0.01           0.5  3.798411
# 3    487.519247        1006.473821      0.01           0.5  3.112764
# 4    509.134552        1004.967042      0.01           0.5  2.617439
#
#    alphaEnzyme    k_mkon    k_koff    p_mkon    p_koff    k_mkcat     k_mKm  \
# 0     0.230912  0.325587  0.492680  0.046112  0.207982  10.810666  2.077767
# 1     0.191769  0.394807  0.542681  0.049611  0.158331  12.699161  3.605082
# 2     0.187384  0.286262  0.466465  0.046303  0.188547   7.578705  3.439337
# 3     0.161575  0.317702  0.579028  0.052530  0.176516  12.421751  3.634139
# 4     0.177708  0.333110  0.580674  0.047376  0.155150   9.781921  3.522384
#
#      p_mkcat     p_mKm  Kinase in solution  Phosphatase in solution  \
# 0  14.983961  0.405463                 353                     1127
# 1  15.819867  0.473824                 264                      703
# 2  13.025158  0.561078                 398                      857
# 3  13.561162  0.592447                 430                      873
# 4  17.515967  0.487298                 430                      890
#
#    Average system X  Average dendrite X  Polarization index  Polarized
# 0          0.515847            0.546400            0.516679      False
# 1          0.525752            0.560122            0.516003      False
# 2          0.515301            0.559077            0.521605      False
# 3          0.523906            0.560070            0.516021      False
# 4          0.555038            0.618737            0.525549      False

# %%
polarized_runs = test_run[test_run['Polarized'] == True]
polarized_runs.shape[0]
# Out:
# 0

# %%
unpolarized_runs = test_run[test_run['Polarized'] == False].copy()
unpolarized_runs.loc[:, 'alphaPIP'] = unpolarized_runs['dPIP'] * 0.01 / (0.5 * 0.5)
unpolarized_runs.shape[0]
# Out:
# 10000

# %%
# sns.scatterplot(data=test_run, x=test_run['k_mkon'], y=test_run['p_mkon'], hue=test_run['Polarized'])
# sns.scatterplot(data=test_run, x=test_run['k_mkcat'], y=test_run['p_mkcat'], hue=test_run['Polarized'])
# sns.scatterplot(data=test_run, x=test_run['p_mkon'], y=test_run['p_koff'], hue=test_run['Polarized'])
# sns.scatterplot(data=test_run, x=test_run['Total Kinase'], y=test_run['Total Phosphatase'], hue=test_run['Polarized'])
# sns.scatterplot(data=test_run, x=test_run['Kinase in solution'], y=test_run['Phosphatase in solution'], hue=test_run['Polarized'])
# sns.scatterplot(data=test_run, x=test_run['k_mKm'], y=test_run['p_mKm'], hue=test_run['Polarized'])
# Out:
# <Axes: xlabel='k_mKm', ylabel='k_mkcat'>

# %%
sns.histplot(data=test_run, x=test_run['dPIP'], hue=test_run['Polarized'])
# sns.histplot(data=test_run, x=test_run['alphaEnzyme'], hue=test_run['Polarized'])
# Out:
# <Axes: xlabel='dPIP', ylabel='Count'>

# %%
sns.scatterplot(data=test_run, x=test_run['k_mkon'], y=test_run['k_koff'], hue=test_run['Polarized'])
# Out:
# <Axes: xlabel='k_mkon', ylabel='k_koff'>

# %%
sns.scatterplot(data=test_run, x=test_run['Total Kinase'], y=test_run['Total Phosphatase'], hue=test_run['Polarized'])
# Out:
# <Axes: xlabel='Total Kinase', ylabel='Total Phosphatase'>

# %%
sns.scatterplot(data=test_run, x=test_run['Kinase in solution'], y=test_run['Phosphatase in solution'], hue=test_run['Polarized'])
# Out:
# <Axes: xlabel='Kinase in solution', ylabel='Phosphatase in solution'>

# %%
sns.scatterplot(data=test_run, x=test_run['k_mKm'], y=test_run['k_mkcat'], hue=test_run['Polarized'])
# Out:
# <Axes: xlabel='k_mKm', ylabel='k_mkcat'>
