# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
four_lobe_1000_random = pd.read_csv("/Users/jerryhuang/Documents/PIPpolarization/data/4_lobe_test_1000runs_1.csv")

# %% [markdown]
# ## Data cleaning and processing

# %%
lobe_data = four_lobe_1000_random.copy()
lobe_data = lobe_data[lobe_data['Average System X'] < 1.0]
lobe_data.head()
# Out:
#    Total Kinase  Total Phosphatase  Timestep  Patch Length      dPIP  \
# 0    730.288043         686.391237      0.01           0.5  3.617439
# 1    148.391699         102.017349      0.01           0.5  3.054060
# 2     41.104056         364.340720      0.01           0.5  4.635594
# 3    401.808612         602.848677      0.01           0.5  3.154170
# 4     46.119672         489.005416      0.01           0.5  4.310107
#
#    alphaEnzyme    k_mkon    k_koff    p_mkon    p_koff  ...    p_mkcat  \
# 0     0.183124  1.018390  2.282588  0.098508  0.304718  ...  34.665588
# 1     0.264500  0.466366  2.426864  0.227080  0.370184  ...  40.547590
# 2     0.225306  1.462611  1.855164  0.125338  0.319990  ...  48.838407
# 3     0.332536  1.354856  1.220446  0.085635  0.465027  ...  15.301901
# 4     0.241539  0.613840  1.704022  0.194912  0.898281  ...  29.916202
#
#       p_mKm  Kinase in Solution  Phosphatase in Solution  Average System X  \
# 0  1.027760                 708                      468          0.775048
# 1  2.104373                 327                       29          0.777463
# 2  0.985892                  29                      210          0.807150
# 3  2.032938                 169                      703          0.809439
# 4  0.897578                  45                      494          0.824795
#
#    Average Dendrite 1 X  Average Dendrite 2 X  Average Dendrite 3 X  \
# 0              0.659104              0.999121              0.993781
# 1              0.657376              0.999499              0.995154
# 2              0.681018              0.999243              0.997368
# 3              0.679527              0.999117              0.997437
# 4              0.737011              0.998681              0.997176
#
#    Average Dendrite 4 X  Average All Dendrites X
# 0              0.810390                 0.865963
# 1              0.813063                 0.865751
# 2              0.788948                 0.867883
# 3              0.793789                 0.866577
# 4              0.845689                 0.896032
#
# [5 rows x 22 columns]

# %%
lobe_data.shape
# Out:
# (210, 22)

# %%
lobe_data.describe()
# Out:
#        Total Kinase  Total Phosphatase      Timestep  Patch Length  \
# count    210.000000         210.000000  2.100000e+02         210.0
# mean     529.571209         521.633293  1.000000e-02           0.5
# std      269.565799         286.089301  1.738869e-18           0.0
# min       20.825547          20.292467  1.000000e-02           0.5
# 25%      329.680786         260.317806  1.000000e-02           0.5
# 50%      517.809935         508.819302  1.000000e-02           0.5
# 75%      730.272658         783.154458  1.000000e-02           0.5
# max      998.714759         999.785680  1.000000e-02           0.5
#
#              dPIP  alphaEnzyme      k_mkon      k_koff      p_mkon  \
# count  210.000000   210.000000  210.000000  210.000000  210.000000
# mean     3.950698     0.255340    0.811020    1.389752    0.137159
# std      0.589453     0.084202    0.404457    0.623842    0.066906
# min      3.012599     0.102117    0.098533    0.255829    0.012461
# 25%      3.416934     0.180501    0.467659    0.825853    0.077892
# 50%      3.921367     0.266057    0.802936    1.380669    0.138431
# 75%      4.456590     0.322745    1.157997    1.911033    0.194442
# max      4.998280     0.399909    1.496344    2.490744    0.249646
#
#            p_koff  ...     p_mkcat       p_mKm  Kinase in Solution  \
# count  210.000000  ...  210.000000  210.000000          210.000000
# mean     0.515636  ...   38.752549    1.390729          470.623810
# std      0.268661  ...   18.729334    0.680099          505.641018
# min      0.040186  ...    3.139224    0.104139            6.000000
# 25%      0.305079  ...   23.699707    0.855063          149.250000
# 50%      0.497244  ...   39.974594    1.457044          292.500000
# 75%      0.767989  ...   53.118289    1.958252          619.750000
# max      0.997305  ...   74.697800    2.465214         2937.000000
#
#        Phosphatase in Solution  Average System X  Average Dendrite 1 X  \
# count               210.000000        210.000000            210.000000
# mean                507.504762          0.647670              0.600996
# std                 491.505735          0.172134              0.216315
# min                  12.000000          0.265819              0.114124
# 25%                 153.500000          0.507534              0.446048
# 50%                 366.500000          0.694565              0.606229
# 75%                 719.250000          0.784569              0.755052
# max                2612.000000          0.987761              0.999650
#
#        Average Dendrite 2 X  Average Dendrite 3 X  Average Dendrite 4 X  \
# count            210.000000            210.000000            210.000000
# mean               0.730271              0.630658              0.637161
# std                0.251076              0.263680              0.252468
# min                0.053588              0.005553              0.088424
# 25%                0.575100              0.418302              0.442141
# 50%                0.801929              0.670711              0.652459
# 75%                0.943553              0.856513              0.844488
# max                0.999990              0.999999              0.999998
#
#        Average All Dendrites X
# count               210.000000
# mean                  0.649819
# std                   0.177084
# min                   0.165839
# 25%                   0.529104
# 50%                   0.664122
# 75%                   0.775815
# max                   0.992973
#
# [8 rows x 22 columns]

# %%
params = lobe_data.iloc[:, :14]
params.head()
# Out:
#    Total Kinase  Total Phosphatase  Timestep  Patch Length      dPIP  \
# 0    730.288043         686.391237      0.01           0.5  3.617439
# 1    148.391699         102.017349      0.01           0.5  3.054060
# 2     41.104056         364.340720      0.01           0.5  4.635594
# 3    401.808612         602.848677      0.01           0.5  3.154170
# 4     46.119672         489.005416      0.01           0.5  4.310107
#
#    alphaEnzyme    k_mkon    k_koff    p_mkon    p_koff    k_mkcat     k_mKm  \
# 0     0.183124  1.018390  2.282588  0.098508  0.304718  24.255372  9.225547
# 1     0.264500  0.466366  2.426864  0.227080  0.370184   2.674679  8.172104
# 2     0.225306  1.462611  1.855164  0.125338  0.319990  47.593286  8.276722
# 3     0.332536  1.354856  1.220446  0.085635  0.465027   6.629644  7.553472
# 4     0.241539  0.613840  1.704022  0.194912  0.898281  15.628541  3.076694
#
#      p_mkcat     p_mKm
# 0  34.665588  1.027760
# 1  40.547590  2.104373
# 2  48.838407  0.985892
# 3  15.301901  2.032938
# 4  29.916202  0.897578

# %%
result = lobe_data.iloc[:, 14:]
result.head()
# Out:
#    Kinase in Solution  Phosphatase in Solution  Average System X  \
# 0                 708                      468          0.775048
# 1                 327                       29          0.777463
# 2                  29                      210          0.807150
# 3                 169                      703          0.809439
# 4                  45                      494          0.824795
#
#    Average Dendrite 1 X  Average Dendrite 2 X  Average Dendrite 3 X  \
# 0              0.659104              0.999121              0.993781
# 1              0.657376              0.999499              0.995154
# 2              0.681018              0.999243              0.997368
# 3              0.679527              0.999117              0.997437
# 4              0.737011              0.998681              0.997176
#
#    Average Dendrite 4 X  Average All Dendrites X
# 0              0.810390                 0.865963
# 1              0.813063                 0.865751
# 2              0.788948                 0.867883
# 3              0.793789                 0.866577
# 4              0.845689                 0.896032

# %%
for i in range(4):
    result['Polarization Index ' + str(i + 1)] = (result['Average Dendrite ' + str(i + 1) + ' X'] / 
                                        (result['Average Dendrite ' + str(i + 1) + ' X'] 
                                         + result['Average System X'])
                                       )
result.head()
# Out:
#    Kinase in Solution  Phosphatase in Solution  Average System X  \
# 0                 708                      468          0.775048
# 1                 327                       29          0.777463
# 2                  29                      210          0.807150
# 3                 169                      703          0.809439
# 4                  45                      494          0.824795
#
#    Average Dendrite 1 X  Average Dendrite 2 X  Average Dendrite 3 X  \
# 0              0.659104              0.999121              0.993781
# 1              0.657376              0.999499              0.995154
# 2              0.681018              0.999243              0.997368
# 3              0.679527              0.999117              0.997437
# 4              0.737011              0.998681              0.997176
#
#    Average Dendrite 4 X  Average All Dendrites X  Polarization Index 1  \
# 0              0.810390                 0.865963              0.459578
# 1              0.813063                 0.865751              0.458153
# 2              0.788948                 0.867883              0.457622
# 3              0.793789                 0.866577              0.456375
# 4              0.845689                 0.896032              0.471897
#
#    Polarization Index 2  Polarization Index 3  Polarization Index 4
# 0              0.563149              0.561830              0.511146
# 1              0.562476              0.561404              0.511191
# 2              0.553170              0.552706              0.494298
# 3              0.552439              0.552023              0.495119
# 4              0.547680              0.547306              0.506254

# %% [markdown]
# ## Data visualization and exploritory analysis

# %% [markdown]
# #### Distributions

# %%
plt.hist(result['Average Dendrite 1 X'])
plt.hist(result['Average Dendrite 2 X'])
plt.hist(result['Average Dendrite 3 X'])
plt.hist(result['Average Dendrite 4 X'])
# Out:
# (array([14.,  3., 18., 21., 15., 27., 24., 22., 28., 38.]),
#  array([0.08842426, 0.17958165, 0.27073903, 0.36189641, 0.45305379,
#         0.54421118, 0.63536856, 0.72652594, 0.81768332, 0.9088407 ,
#         0.99999809]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(16, 8))
plt.subplot(221)
sns.violinplot(data=result, x='Average Dendrite 1 X')
plt.subplot(222)
sns.violinplot(data=result, x='Average Dendrite 2 X')
plt.subplot(223)
sns.violinplot(data=result, x='Average Dendrite 3 X')
plt.subplot(224)
sns.violinplot(data=result, x='Average Dendrite 4 X')
# Out:
# <Axes: xlabel='Average Dendrite 4 X'>

# %% [markdown]
# #### Heatmaps

# %%
correlation_matrix = lobe_data.corr()
sns.heatmap(data=correlation_matrix)
# Out:
# <Axes: >

# %%
correlation_matrix = result.corr()
sns.heatmap(data=correlation_matrix)
# Out:
# <Axes: >

# %%
correlation_matrix = params.corr()
sns.heatmap(data=correlation_matrix)
# Out:
# <Axes: >

# %% [markdown]
# #### Scatter plots

# %%
plt.figure(figsize=(16, 8))
plt.subplot(221)
sns.scatterplot(x=params['k_mkon'], y=result['Kinase in Solution'])
plt.subplot(222)
sns.scatterplot(x=params['k_koff'], y=result['Kinase in Solution'])
plt.subplot(223)
sns.scatterplot(x=params['p_mkon'], y=result['Phosphatase in Solution'])
plt.subplot(224)
sns.scatterplot(x=params['p_koff'], y=result['Phosphatase in Solution'])
# Out:
# <Axes: xlabel='p_koff', ylabel='Phosphatase in Solution'>

# %% [markdown]
# ## Feature Engineering
