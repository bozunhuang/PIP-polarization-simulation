# %%
import numpy as np
import matplotlib as plt
import pandas as pd
import seaborn as sns

# %%
test_run = pd.read_csv("/Users/jerryhuang/Documents/PIPpolarization/data/test_run_var_1.csv")

# %%
test_run.head(10)
# Out:
#    Total Kinase  Total Phosphatase  Timestep  Patch Length  dPIP  alphaEnzyme  \
# 0        487.50             1000.0      0.01           0.5   3.0          0.2
# 1        488.75             1000.0      0.01           0.5   3.0          0.2
# 2        490.00             1000.0      0.01           0.5   3.0          0.2
# 3        491.25             1000.0      0.01           0.5   3.0          0.2
# 4        492.50             1000.0      0.01           0.5   3.0          0.2
# 5        493.75             1000.0      0.01           0.5   3.0          0.2
# 6        495.00             1000.0      0.01           0.5   3.0          0.2
# 7        496.25             1000.0      0.01           0.5   3.0          0.2
# 8        497.50             1000.0      0.01           0.5   3.0          0.2
# 9        498.75             1000.0      0.01           0.5   3.0          0.2
#
#    k_mkon  k_koff  p_mkon  p_koff  k_mkcat  k_mKm  p_mkcat  p_mKm  \
# 0     0.3     0.5    0.05     0.2     10.0    2.0     15.0    0.5
# 1     0.3     0.5    0.05     0.2     10.0    2.0     15.0    0.5
# 2     0.3     0.5    0.05     0.2     10.0    2.0     15.0    0.5
# 3     0.3     0.5    0.05     0.2     10.0    2.0     15.0    0.5
# 4     0.3     0.5    0.05     0.2     10.0    2.0     15.0    0.5
# 5     0.3     0.5    0.05     0.2     10.0    2.0     15.0    0.5
# 6     0.3     0.5    0.05     0.2     10.0    2.0     15.0    0.5
# 7     0.3     0.5    0.05     0.2     10.0    2.0     15.0    0.5
# 8     0.3     0.5    0.05     0.2     10.0    2.0     15.0    0.5
# 9     0.3     0.5    0.05     0.2     10.0    2.0     15.0    0.5
#
#    Kinase in solution  Phosphatase in solution  Average system X  \
# 0                 301                      844          0.335656
# 1                 488                      941          0.291265
# 2                 464                     1001          0.331589
# 3                 447                      998          0.323517
# 4                 475                      998          0.342782
# 5                 486                     1026          0.387100
# 6                 465                      970          0.357074
# 7                 508                      992          0.310243
# 8                 538                     1001          0.299870
# 9                 493                      989          0.302213
#
#    Average dendrite X  Polarization index
# 0            0.334255            0.498954
# 1            0.210195            0.419166
# 2            0.078654            0.191726
# 3            0.527565            0.619875
# 4            0.391671            0.533282
# 5            0.630810            0.619711
# 6            0.643508            0.643133
# 7            0.769038            0.712546
# 8            0.802274            0.727921
# 9            0.981317            0.764545

# %%
test_run["Polarized"] = test_run["Polarization index"].map(lambda x: x >= 0.7)
test_run.describe()
# Out:
#        Total Kinase  Total Phosphatase    Timestep  Patch Length        dPIP  \
# count    294.000000         294.000000  294.000000    294.000000  294.000000
# mean     499.957483         999.914966    0.009999      0.499957    2.999745
# std        1.889746           3.779491    0.000038      0.001890    0.011338
# min      487.500000         975.000000    0.009750      0.487500    2.925000
# 25%      500.000000        1000.000000    0.010000      0.500000    3.000000
# 50%      500.000000        1000.000000    0.010000      0.500000    3.000000
# 75%      500.000000        1000.000000    0.010000      0.500000    3.000000
# max      511.250000        1022.500000    0.010225      0.511250    3.067500
#
#        alphaEnzyme      k_mkon      k_koff      p_mkon      p_koff  \
# count   294.000000  294.000000  294.000000  294.000000  294.000000
# mean      0.199983    0.299974    0.499957    0.049996    0.199983
# std       0.000756    0.001134    0.001890    0.000189    0.000756
# min       0.195000    0.292500    0.487500    0.048750    0.195000
# 25%       0.200000    0.300000    0.500000    0.050000    0.200000
# 50%       0.200000    0.300000    0.500000    0.050000    0.200000
# 75%       0.200000    0.300000    0.500000    0.050000    0.200000
# max       0.204500    0.306750    0.511250    0.051125    0.204500
#
#           k_mkcat       k_mKm     p_mkcat       p_mKm  Kinase in solution  \
# count  294.000000  294.000000  294.000000  294.000000          294.000000
# mean     9.999150    1.999830   14.998724    0.499957          497.326531
# std      0.037795    0.007559    0.056692    0.001890           22.597128
# min      9.750000    1.950000   14.625000    0.487500          301.000000
# 25%     10.000000    2.000000   15.000000    0.500000          488.000000
# 50%     10.000000    2.000000   15.000000    0.500000          499.000000
# 75%     10.000000    2.000000   15.000000    0.500000          511.000000
# max     10.225000    2.045000   15.337500    0.511250          538.000000
#
#        Phosphatase in solution  Average system X  Average dendrite X  \
# count               294.000000        294.000000          294.000000
# mean                999.931973          0.944205            0.981861
# std                  11.820420          0.168878            0.099553
# min                 844.000000          0.291265            0.078654
# 25%                1000.000000          1.000000            1.000000
# 50%                1000.000000          1.000000            1.000000
# 75%                1000.000000          1.000000            1.000000
# max                1045.000000          1.000000            1.000000
#
#        Polarization index
# count          294.000000
# mean             0.512997
# std              0.051453
# min              0.191726
# 25%              0.500000
# 50%              0.500000
# 75%              0.500000
# max              0.764545

# %%
polarized_runs = test_run[test_run['Polarized'] == True]
polarized_runs.shape[0]
# Out:
# 7

# %%
unpolarized_runs = test_run[test_run['Polarized'] == False].copy()
unpolarized_runs.loc[:, 'alphaPIP'] = unpolarized_runs['dPIP'] * 0.01 / (0.5 * 0.5)
unpolarized_runs.shape[0]
# Out:
# 287

# %%
num_k = test_run.loc[:9]
num_p = test_run.loc[10:19]
sns.scatterplot(data=num_k, x='Total Kinase', y='Average system X')
sns.scatterplot(data=num_k, x='Total Kinase', y='Average dendrite X')
# sns.scatterplot(data=num_p, x=test_run['Total Phosphatase'], y=test_run['Polarization index'])
# Out:
# <Axes: xlabel='Total Kinase', ylabel='Average system X'>

# %%
sns.histplot(data=test_run, x='Polarization index', hue=test_run['Polarized'])
# Out:
# <Axes: xlabel='Polarization index', ylabel='Count'>

# %%
sns.scatterplot(data=test_run, x='k_mkon', y='Polarization index')
# sns.scatterplot(data=test_run, x=test_run['k_koff'], y=test_run['Polarization index'])
# Out:
# <Axes: xlabel='k_mkon', ylabel='Polarization index'>

# %%
# sns.scatterplot(data=test_run, x=test_run['k_mkon'], y=test_run['p_mkon'], hue=test_run['Polarized'])
# sns.scatterplot(data=test_run, x=test_run['k_mkcat'], y=test_run['p_mkcat'], hue=test_run['Polarized'])
# sns.scatterplot(data=test_run, x=test_run['p_mkon'], y=test_run['p_koff'], hue=test_run['Polarized'])
# sns.scatterplot(data=test_run, x=test_run['Total Kinase'], y=test_run['Total Phosphatase'], hue=test_run['Polarized'])
# sns.scatterplot(data=test_run, x=test_run['Kinase in solution'], y=test_run['Phosphatase in solution'], hue=test_run['Polarized'])
# sns.scatterplot(data=test_run, x=test_run['k_mKm'], y=test_run['p_mKm'], hue=test_run['Polarized'])
# Out:
# <Axes: xlabel='k_mKm', ylabel='k_mkcat'>

# %%
sns.histplot(data=test_run, x=test_run['dPIP'], hue=test_run['Polarized'])
# sns.histplot(data=test_run, x=test_run['alphaEnzyme'], hue=test_run['Polarized'])
# Out:
# <Axes: xlabel='dPIP', ylabel='Count'>

# %%
sns.scatterplot(data=test_run, x='k_mkon', y=test_run['k_koff'], hue=test_run['Polarized'])
# Out:
# <Axes: xlabel='k_mkon', ylabel='k_koff'>

# %%
sns.scatterplot(data=test_run, x=test_run['Total Kinase'], y=test_run['Total Phosphatase'], hue=test_run['Polarized'])
# Out:
# <Axes: xlabel='Total Kinase', ylabel='Total Phosphatase'>

# %%
sns.scatterplot(data=test_run, x=test_run['Kinase in solution'], y=test_run['Phosphatase in solution'], hue=test_run['Polarized'])
# Out:
# <Axes: xlabel='Kinase in solution', ylabel='Phosphatase in solution'>

# %%
sns.scatterplot(data=test_run, x=test_run['k_mKm'], y=test_run['k_mkcat'], hue=test_run['Polarized'])
# Out:
# <Axes: xlabel='k_mKm', ylabel='k_mkcat'>
