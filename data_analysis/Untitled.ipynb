# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
fixed = pd.read_csv("/Users/jerryhuang/Documents/PIPpolarization/data/4_lobe_test_1000runs_2.csv")
